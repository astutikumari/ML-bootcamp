# %% [markdown]
# <a href="https://colab.research.google.com/github/astutikumari/ML-bootcamp/blob/main/ASTUTI_polynomial_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Corn_Yield.csv')
X = dataset.iloc[:, :-1].values
Y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
pf = PolynomialFeatures(degree = 2)
X_poly = pf.fit_transform(X)
poly_reg = LinearRegression()
poly_reg.fit(X_poly, Y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(X, Y, color = 'red')
plt.plot(X, lin_reg.predict(X), color = 'blue')
plt.title('Yeild vs Fertilizer used(Linear Regression)')
plt.xlabel('Fertilizer Used')
plt.ylabel('Corn Yield')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(X, Y, color = 'red')
plt.plot(X, poly_reg.predict(X_poly), color = 'blue')
plt.title('Yield vs Fertilizer used(Polynomial Regression)')
plt.xlabel('Fertilizer Used')
plt.ylabel('Corn Yield')
# Out:
# Text(0, 0.5, 'Corn Yield')

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
fertilizer = input ("enter the value of fertilizer used")
fert = float(fertilizer)
# Out:
# enter the value of fertilizer used16.5

# %%
lin_reg.predict([[fert]])
# Out:
# array([19.42495758])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
poly_reg.predict(pf.fit_transform([[16.5]]))
# Out:
# array([29.45867643])
